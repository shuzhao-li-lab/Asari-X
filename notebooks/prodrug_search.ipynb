# %% [markdown]
# In this test we will use Asari-X to search for pro-drug, drug pairs in U2C dataset.
#
# The pro-drug signatures should be correlated with its drug metabolites.
#
# ChatGPT generated examples to search for:
#
# | **Prodrug**               | **Active Drug**            | Likely Metabolic Pathway / Enzyme     |
# |---------------------------|----------------------------|----------------------------------------|
# | **Valacyclovir**          | **Acyclovir**              | Hepatic esterases (CES1/2)             |
# | **Oseltamivir**           | **Oseltamivir carboxylate**| Hepatic carboxylesterase (CES1)        |
# | **Clopidogrel**           | **Thiol active metabolite**| CYP2C19 + CES1                          |
# | **Enalapril**             | **Enalaprilat**            | Hepatic carboxylesterase               |
# | **Capecitabine**          | **5-FU**                   | Carboxylesterases → CYP2C9 → TP        |
# | **Fosphenytoin**          | **Phenytoin**              | Alkaline phosphatases + hepatic enzymes|
# | **Tenofovir alafenamide**| **Tenofovir**              | CES1 in hepatocytes                    |
# | **Sulindac**              | **Sulindac sulfide**       | Hepatic reduction (microsomal)         |
# | **Lisdexamfetamine**      | **Dextroamphetamine**      | Primarily blood, some hepatic          |
# | **Prednisone**            | **Prednisolone**           | Hepatic 11β-HSD                        |
# | **Famciclovir**           | **Penciclovir**            | Hepatic esterases                      |
#
# We will be using the example:
#
# Valcyclovir -> Acyclovir
